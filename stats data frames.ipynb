# %%
import pandas as pd

# %%
df=pd.read_csv("Dataframe.csv")
# Out:
#      סוג: ממוצע, זמן מיצוע: 24 שעות, Period:01/01/2008 00:01 - 01/01/2018 00:00  \
# 0                                                   NaN
# 1                                            תאריך ושעה
# 2                                                   NaN
# 3                                                   NaN
# 4                                                 39449
# ...                                                 ...
# 3662                                 תאריך נתון מקסימלי
# 3663                                   שעה נתון מקסימלי
# 3664                                            מינימלי
# 3665                                 תאריך נתון מינימלי
# 3666                                   שעה נתון מינימלי
#
#         Unnamed: 1  Unnamed: 2                     Unnamed: 3  Unnamed: 4  \
# 0              NaN         NaN                            NaN         NaN
# 1     חולון, חולון         NaN  תל אביב-יפו, רחוב יהודה המכבי         NaN
# ...
